# %% [markdown]
# # Git

# %%
ls
# Out:
# ai_project/  git_setup.txt  Makefile  requirements.txt  Stock_Broker/  venv/

# %%
cd Stock_Broker
# Out:
# [Errno 2] No such file or directory: 'Stock_Broker'
# /content/drive/MyDrive/ProCoder/Stock_Broker

# %%
# !git checkout -b fb_database_connectivity
# Out:
# Switched to a new branch 'fb_database_connectivity'

# %%
! git status
# Out:
# On branch fb_database_connectivity
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Makefile
# 	ai_project/
# 	git_setup.txt
# 	requirements.txt
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
ls
# Out:
# ai_project/  git_setup.txt  Makefile  README.md  requirements.txt  venv/

# %%
git s

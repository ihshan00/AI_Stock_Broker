# %% [markdown]
# # Git

# %%
ls
# Out:
# ai_project/  git_setup.txt  Makefile  requirements.txt  Stock_Broker/  venv/

# %%
cd Stock_Broker
# Out:
# [Errno 2] No such file or directory: 'Stock_Broker'
# /content/drive/MyDrive/ProCoder/Stock_Broker

# %%
# !git checkout -b fb_database_connectivity
# Out:
# Switched to a new branch 'fb_database_connectivity'

# %%
! git status
# Out:
# On branch fb_database_connectivity
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Makefile
# 	ai_project/
# 	git_setup.txt
# 	requirements.txt
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
ls
# Out:
# ai_project/  git_setup.txt  Makefile  README.md  requirements.txt  venv/

# %%
! git add .

# %%
! git status
# Out:
# On branch fb_database_connectivity
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   Makefile
# 	new file:   ai_project/config/config.yaml
# 	new file:   ai_project/data/untitled
# 	new file:   ai_project/notebooks/AI_Assitant_Stock_Broker.ipynb
# 	new file:   ai_project/notebooks/db_connect.ipynb
# 	new file:   ai_project/src/handlers/__init__.py
# 	new file:   ai_project/src/llm/__init__.py
# 	new file:   ai_project/src/prompt/__init__.py
# 	new file:   ai_project/src/utils/__init__.py
# 	new file:   ai_project/test/test_.py
# 	new file:   git_setup.txt
# 	new file:   requirements.txt

# %%
! git commit -m "Initialized Project"
# Out:
# [fb_database_connectivity cc2f357] Initialized Project
#  12 files changed, 40 insertions(+)
#  create mode 100644 Makefile
#  create mode 100644 ai_project/config/config.yaml
#  create mode 100644 ai_project/data/untitled
#  create mode 100644 ai_project/notebooks/AI_Assitant_Stock_Broker.ipynb
#  create mode 100644 ai_project/notebooks/db_connect.ipynb
#  create mode 100644 ai_project/src/handlers/__init__.py
#  create mode 100644 ai_project/src/llm/__init__.py
#  create mode 100644 ai_project/src/prompt/__init__.py
#  create mode 100644 ai_project/src/utils/__init__.py
#  create mode 100644 ai_project/test/test_.py
#  create mode 100644 git_setup.txt
#  create mode 100644 requirements.txt

# %%
! git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> fb_database_connectivity

# %%
# !git push origin fb_database_connectivity
# Out:
# fatal: not a git repository (or any of the parent directories): .git
